# %% [markdown]
# # Notebook Summary
# In this notebook we will use the sentence_transformers package to encode text features in the pairs dataset and compute their cosine similarities (dot-products). We will also calculate the geodesic distances between pairs.

# %%
# import basic packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import pairs dataset
pairs = pd.read_csv('pairs.csv')

# %% [markdown]
# ## Vector Encoding of Text Features Using BERT
# We'll use a pretrained multilanguage BERT model.

# %%
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 6.7 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 57.7 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.12.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 60.6 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 14.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence_transformers) (4.1.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 61.6 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 69.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (4.11.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.7.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=cc19ee158237f54bda767cd3085b8799b283f8b10aef339feffc44d8c6ae0ff8
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.20.1

# %%
# import SentenceTransformers and cosine similarity function

from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/snapshot_download.py:11: FutureWarning: snapshot_download.py has been made private and will no longer be available from version 0.11. Please use `from huggingface_hub import snapshot_download` to import the only public function in this module. Other members of the file may be changed without a deprecation notice.
#   FutureWarning,

# %% [markdown]
# We will initialize a pre-trained language model selected from this list: https://www.sbert.net/docs/pretrained_models.html. It will be chosen for simultaneous high performance and low computational overhead. We also want a multi-lingual model.

# %%
# Initialize transformer model
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/file_download.py:563: FutureWarning: `cached_download` is the legacy way to download files from the HF hub, please consider upgrading to `hf_hub_download`
#   FutureWarning,
# Downloading:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.8M [00:00<?, ?B/s]

# %%
features = ['name', 'address', 'city', 'state', 'zip', 'country', 'url', 'phone', 'categories']

for f in features:
  missing_bools = pairs[f+'_1'].isnull() | pairs[f+'_2'].isnull() #boolean series where a value of the feature is missing for each
  filled_bools = ~missing_bools #boolean series where both values of the feature are filled

  #Vector encode text features, where filled, for all pairs.
  encode_1 = model.encode(pairs[filled_bools][f+'_1'].values) 
  encode_2 = model.encode(pairs[filled_bools][f+'_2'].values)
  #compute cosine similarities with lazy loading (i.e. looping) to save RAM
  n = len(encode_1)
  sims = np.zeros(n)
  for i in range(n):
    sims[i]=cos_sim(encode_1[i],encode_2[i])
  pairs[f+'_sim']=np.zeros(len(pairs)) # create new column of feature similarities and set all to zero
  pairs.loc[filled_bools,f+'_sim']=sims # add calculated similarities where values are filled
  mean_sim = np.mean(sims) #mean cosine similarity
  pairs.loc[missing_bools,f+'_sim']=mean_sim*np.ones(len(pairs[missing_bools])) #put mean similarities where there is a missing value - mean imputation.

# %%
pairs.to_csv('pairs.csv')

# %% [markdown]
# ## Computing Geodesic distances between pairs

# %%
#import geodesic distance from geopy
from geopy.distance import geodesic

# %%
# Takes two lists of the same length, returns a list of pairs
def to_pair(l1, l2):
    return [(l1[i],l2[i]) for i in range(len(l1))]

# Takes two lists of long/lat pairs, returns their geodesic distance
def get_dists(l1, l2):
    return [geodesic(l1[i], l2[i]).km for i in range(len(l1))]

# %%
loc1s = to_pair(pairs['latitude_1'], pairs['longitude_1'])
loc2s = to_pair(pairs['latitude_2'], pairs['longitude_2'])
pairs['distance'] = get_dists(loc1s, loc2s)

# %%
pairs.to_csv('pairs.csv')

# %% [markdown]
# ## Removing Outliers

# %%
top = pairs.distance[pairs['match']].quantile(0.99)
long_indices = pairs[pairs['match']][pairs['distance']>=top].index
pairs_clean =pairs.copy()
pairs_clean.drop(long_indices,inplace=True)

bottom = pairs.distance[pairs['match']==False].quantile(0.01)
short_indices = pairs[pairs['match']==False][pairs['distance']<=bottom].index
pairs_clean.drop(short_indices,inplace=True)

pairs_clean.to_csv('pairs_clean.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
pairs_clean.head(50)
# Out:
#                 id_1                                       name_1  latitude_1  \
# 0   E_000001272c6c5d                         Café Stad Oudenaarde   50.859975
# 1   E_000008a8ba4f48                                     Turkcell   37.844510
# 2   E_000023d8f4be44                                   Island Spa   14.518970
# 3   E_00007dcd2bb53f                            TOGO'S Sandwiches   38.257797
# 4   E_0000c362229d93                                   Coffee Cat    7.082218
# 5   E_0000c566a81ea1                                     つじ田 味噌の章   35.694796
# 6   E_0000d9e584ed9f                Signature Properties Savannah   32.012582
# 7   E_00011cca3f0bd6                               Inner Workings   35.686930
# 8   E_00015cd7e0227f                                 Lake Destiny   28.643613
# 9   E_0001827d6b4ee2                           Marshall Boya Bayi   38.534796
# 10  E_000184ea12d0f0                                     ざま駅前歯科医院   35.480396
# 11  E_0001a397f67ad5  Dale City Truck-Only Safety Rest Area North   38.599821
# 12  E_00024204e83804                                       Lukoil   51.172940
# 13  E_000288f2046ce3                                         Lidl   51.060776
# 14  E_0002b0ae551c83                              イオン乙金ショッピングセンター   33.543487
# 15  E_0002b7964ffc2a                                Del Mar Motel   32.962563
# 16  E_0002baf74f8aa3                 Spielplatz am Goslarer Platz   52.525679
# 17  E_0003121444b756                                Asmak El-Hamd   27.182325
# 18  E_00037fb71d569d                          Траса #1 / Slope #1   48.356993
# 19  E_0003a95be7fc68                     Administration Communale   50.602711
# 20  E_0003aacb9b7592                            Het Suikerbroodje   50.900743
# 21  E_0003b15b0cc3b3                                   PETIT TONG   37.578709
# 22  E_0003d64daed560                           Handhu Runba Cafe'    3.593957
# 23  E_00043afe4abc1f                                      sala 40  -35.434644
# 24  E_0004404e151b90                       ร้านขายยา ตลาดสันติสุข   18.843509
# 25  E_00045931e0bb56              Trinity United Methodist Church   29.705895
# 26  E_00045e5c3e3ed6     La Quinta Inn & Suites Memphis Wolfchase   35.203170
# 27  E_00045e5c3e3ed6     La Quinta Inn & Suites Memphis Wolfchase   35.203170
# 28  E_000477147d08e6                                     Tesco HQ   47.450562
# 29  E_0004d7b2919f69               Block 525 Bedok North Street 3    1.334889
# 30  E_0004d92056a129                    Администрация г. Кемерово   55.355278
# 31  E_0004df74e86f9b                             Контур-Ойл Групп   55.664858
# 32  E_0004fb8ca65bd0                                    Глушко 33   55.786813
# 33  E_0004fb8ca65bd0                                    Глушко 33   55.786813
# 34  E_00052849d90a2e                                 Bo Mao Beach   10.701961
# 35  E_000587836c4320                                        甲武信小屋   35.907158
# 36  E_00058c921cbefe                       Dominó Plaza La Serena  -29.912911
# 37  E_0005fcad52004f                                   Kipa Extra   36.909247
# 38  E_000610912e6c85                                  Modrý salón   48.141768
# 39  E_000643f43d5c02                                    ПроМедика   41.992992
# 40  E_00065d23dbbec8                             ロイヤル キッチン 京都高島屋店   35.003274
# 41  E_0006a5fa76742d                                     博多らーめん四神   35.950399
# 42  E_0006be64b1557d           さいたまスーパーアリーナ (Saitama Super Arena)   35.895121
# 43  E_0006be64b1557d           さいたまスーパーアリーナ (Saitama Super Arena)   35.895121
# 44  E_0006be64b1557d           さいたまスーパーアリーナ (Saitama Super Arena)   35.895121
# 45  E_0006be64b1557d           さいたまスーパーアリーナ (Saitama Super Arena)   35.895121
# 46  E_0006be64b1557d           さいたまスーパーアリーナ (Saitama Super Arena)   35.895121
# 47  E_00070fdfc2d9ef                                 Pathé Rialto   46.209190
# 48  E_0007344ec28475                      Block D Computer Lab 21    3.063748
# 49  E_000735647a8993                            Alibeyköy Meydanı   41.074552
#
#     longitude_1                                    address_1  \
# 0      3.634196                                  Abdijstraat
# 1     27.844202                       Adnan Menderes Bulvarı
# 2    121.018702  5th Flr, Newport Mall, Resorts World Manila
# 3   -122.064599                     1380 Holiday Ln., Ste. B
# 4    125.610244                                F. Torres St.
# 5    139.767348                                     神田小川町1-1
# 6    -81.113156                      100 Commercial Ct Ste C
# 7   -105.939167                         Serving General Area
# 8    -81.389132                                          NaN
# 9     30.548005                İplik Mah. Zafer Sok. 4 Şuhut
# 10   139.400101                                    入谷東3-60-2
# 11   -77.312595                          Interstate 95 North
# 12     4.125157                                Vlyminckshoek
# 13    13.681555                           Cossebauder Str. 6
# 14   130.496612                          乙金3-23-1 / 乙金3-24-1
# 15  -117.267844                              1702 Coast Blvd
# 16    13.313819                                          NaN
# 17    31.177043                              Seti El Awal St
# 18    24.411485                                     Буковель
# 19     3.386306                                          NaN
# 20     4.282392                                  Dorpsstraat
# 21   126.971687                                종로구 자하문로 40-1
# 22    72.883635                                   Machafushi
# 23   -71.619194                     Facultad Cs. de la Salud
# 24    99.075838                                 ตลาดสันติสุข
# 25   -82.384165                             4000 NW 53rd Ave
# 26   -89.778486                      2839 New Brunswick Road
# 27   -89.778486                      2839 New Brunswick Road
# 28    18.963587                              Kinizsi út 1-3.
# 29   103.928750                   Block 525 Bedok North St 3
# 30    86.086916                         Советский просп., 54
# 31    37.539583            ул. Воронцовские Пруды, 1, стр. 1
# 32    49.228112                                          NaN
# 33    49.228112                                          NaN
# 34    99.365598                         National Hwy No 4004
# 35   138.730793                                     大滝3638-8
# 36   -71.258130    Av. Alberto Solari 1400, Patio de Comidas
# 37    30.674846                                     Kipa AVM
# 38    17.122401                           Primaciálne nám. 1
# 39    21.426235                   Свети Кирил и Методиј 50/5
# 40   135.769077                                      下京区真町52
# 41   139.992471                                        中央3-2
# 42   139.630558                                      中央区新都心8
# 43   139.630558                                      中央区新都心8
# 44   139.630558                                      中央区新都心8
# 45   139.630558                                      中央区新都心8
# 46   139.630558                                      中央区新都心8
# 47     6.141879                           Blvd James-Fazy 33
# 48   101.617074          Taylor's University Lakeside Campus
# 49    28.945703                                    Alibeyköy
#
#               city_1             state_1     zip_1 country_1  \
# 0         Nederename     Oost-Vlaanderen      9700        BE
# 1                NaN                 NaN       NaN        TR
# 2         Pasay City        Metro Manila       NaN        PH
# 3          Fairfield                  CA     94534        US
# 4         Davao City        Davao Region      8000        PH
# 5               千代田区                 東京都  101-0052        JP
# 6           Savannah                  GA     31406        US
# 7           Santa Fe                  NM     87501        US
# 8           Maitland                  FL     32751        US
# 9     Afyonkarahisar                 NaN       NaN        TR
# 10               座間市                神奈川県  252-0028        JP
# 11         Montclair                  VA     22026        US
# 12      Sint-Niklaas       Vlaams Gewest      9100        BE
# 13     Dresden-Cotta             Sachsen     01157        DE
# 14              大野城市                 福岡県  816-0902        JP
# 15         San Diego                  CA     92014        US
# 16            Berlin              Berlin       NaN        DE
# 17             Asyūţ    Muḩāfaz̧at Asyūţ       NaN        EG
# 18          Буковель            Буковель       NaN        UA
# 19           Tournai             Hainaut       NaN        BE
# 20           Relegem                 NaN       NaN        BE
# 21               서울시                 NaN     03043        KR
# 22  Alif Dhaal Atoll      North Province       NaN        MV
# 23               NaN                 NaN       NaN        CL
# 24               NaN                 NaN       NaN        TH
# 25       Gainesville                  FL     32653        US
# 26           Memphis                  TN     38133        US
# 27           Memphis                  TN     38133        US
# 28           Budaörs                Pest      2040        HU
# 29               NaN                 NaN    460525        SG
# 30          Кемерово                 NaN    650000        RU
# 31    Москва, Moscow              Москва    117630        RU
# 32               NaN                 NaN       NaN        RU
# 33               NaN                 NaN       NaN        RU
# 34   Pathio District            Chumphon     86160        TH
# 35               秩父市                 埼玉県  369-1901        JP
# 36         La Serena  Región de Coquimbo       NaN        CL
# 37           Antalya             Türkiye     07090        TR
# 38        Bratislava   Bratislavský kraj    811 01        SK
# 39            Скопје                 NaN      1000        MK
# 40               京都市                 京都府  600-8520        JP
# 41               守谷市                 茨城県  302-0115        JP
# 42             さいたま市                 埼玉県  330-9109        JP
# 43             さいたま市                 埼玉県  330-9109        JP
# 44             さいたま市                 埼玉県  330-9109        JP
# 45             さいたま市                 埼玉県  330-9109        JP
# 46             さいたま市                 埼玉県  330-9109        JP
# 47            Genève                  GE      1201        CH
# 48               NaN                 NaN       NaN        MY
# 49              Eyüp            İstanbul       NaN        TR
#
#                                                 url_1  ...  name_sim  \
# 0                                                 NaN  ...  0.966012
# 1                                                 NaN  ...  1.000000
# 2                                                 NaN  ...  0.820979
# 3   https://locations.togos.com/ll/US/CA/Fairfield...  ...  0.774163
# 4                                                 NaN  ...  0.781658
# 5                        https://tsukemen-tsujita.com  ...  0.879329
# 6               http://www.oursignatureproperties.com  ...  1.000000
# 7                     http://innerworkingsmassage.com  ...  1.000000
# 8                                                 NaN  ...  0.871865
# 9                         http://www.marshallboya.com  ...  1.000000
# 10                            https://www.z-shika.com  ...  0.587718
# 11  http://www.virginiadot.org/travel/map-ra-dalec...  ...  0.497279
# 12                                                NaN  ...  0.581668
# 13                                https://www.lidl.de  ...  1.000000
# 14                      http://otogana.aeonkyushu.com  ...  0.646667
# 15                                                NaN  ...  0.842063
# 16                                                NaN  ...  0.702528
# 17                                                NaN  ...  0.386812
# 18                                                NaN  ...  0.532339
# 19                                                NaN  ...  0.703913
# 20                                                NaN  ...  0.950212
# 21                      http://petittong.allplaces.kr  ...  0.554435
# 22                                                NaN  ...  0.762777
# 23                                                NaN  ...  0.675651
# 24                                                NaN  ...  0.755324
# 25                          http://www.TrinityGNV.org  ...  0.983226
# 26        http://www.laquintamemphiswolfchasearea.com  ...  1.000000
# 27        http://www.laquintamemphiswolfchasearea.com  ...  0.783747
# 28                                                NaN  ...  0.795441
# 29                                                NaN  ...  0.867760
# 30                                                NaN  ...  0.822091
# 31                                                NaN  ...  0.474344
# 32                                                NaN  ...  0.956562
# 33                                                NaN  ...  0.944303
# 34                                                NaN  ...  0.823758
# 35                              http://www.kobusi.com  ...  1.000000
# 36                               http://www.domino.cl  ...  0.336619
# 37                                                NaN  ...  1.000000
# 38                                                NaN  ...  0.722964
# 39                            http://promedika.com.mk  ...  0.506688
# 40                                                NaN  ...  0.825196
# 41                               http://www.nre.co.jp  ...  0.733020
# 42                    https://www.saitama-arena.co.jp  ...  0.558045
# 43                    https://www.saitama-arena.co.jp  ...  0.554574
# 44                    https://www.saitama-arena.co.jp  ...  0.532697
# 45                    https://www.saitama-arena.co.jp  ...  0.933672
# 46                    https://www.saitama-arena.co.jp  ...  0.421675
# 47                                http://www.pathe.ch  ...  0.801720
# 48                                                NaN  ...  0.511537
# 49                                                NaN  ...  0.560310
#
#    address_sim  city_sim state_sim   zip_sim  country_sim   url_sim phone_sim  \
# 0     0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 1     0.467641  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 2     0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 3     0.739737  1.000000  1.000001  0.977210          1.0  0.842439  0.930410
# 4     0.157384  1.000000  1.000000  1.000000          1.0  0.842439  0.930410
# 5     0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 6     0.422008  1.000000  1.000000  1.000000          1.0  0.842439  0.930410
# 7     1.000000  1.000000  1.000000  1.000000          1.0  0.842439  0.778478
# 8     0.739737  1.000000  1.000000  1.000000          1.0  0.842439  0.930410
# 9     0.735139  1.000000  0.911244  0.977210          1.0  1.000000  0.981449
# 10    0.976229  1.000000  1.000000  1.000000          1.0  0.465308  0.930410
# 11    0.739737  0.330179  1.000000  1.000000          1.0  0.842439  0.930410
# 12    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 13    0.671083  0.237031  0.911244  0.790825          1.0  0.954592  1.000000
# 14    0.927733  1.000000  1.000000  0.999999          1.0  0.842439  0.930410
# 15    0.900370  1.000000  1.000001  1.000000          1.0  0.842439  0.930410
# 16    0.739737  0.999999  0.999999  0.977210          1.0  0.842439  0.930410
# 17    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 18    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 19    0.739737  1.000000  0.380445  0.977210          1.0  0.842439  0.930410
# 20    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 21    0.514676  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 22    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 23    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 24    0.377011  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 25    0.739737  1.000000  1.000000  0.970233          1.0  0.842439  0.930410
# 26    0.889435  1.000000  1.000000  1.000000          1.0  0.508161  0.874033
# 27    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 28    0.926794  1.000000  0.225064  1.000000          1.0  0.842439  0.930410
# 29    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 30    1.000000  0.999999  0.911244  0.977210          1.0  0.842439  0.930410
# 31    0.739737  0.954161  0.996355  0.952761          1.0  0.842439  0.930410
# 32    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 33    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 34    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 35    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 36    0.849977  1.000001  0.911244  0.977210          1.0  0.842439  0.930410
# 37    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 38    0.530219  1.000001  1.000000  1.000000          1.0  0.842439  0.930410
# 39    0.463578  1.000000  0.911244  0.977210          1.0  0.842439  0.930410
# 40    1.000000  1.000000  0.951090  0.971661          1.0  0.842439  0.930410
# 41    1.000000  1.000001  1.000000  0.977210          1.0  0.842439  0.921987
# 42    0.739737  0.870807  1.000000  0.912915          1.0  0.842439  0.930410
# 43    0.739737  0.870807  1.000000  0.912915          1.0  0.842439  0.930410
# 44    1.000000  1.000000  1.000000  0.912915          1.0  0.801912  0.930410
# 45    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 46    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 47    0.739737  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 48    1.000000  0.896136  0.911244  0.977210          1.0  0.842439  0.930410
# 49    0.739737  0.896136  1.000000  0.977210          1.0  0.842439  0.930410
#
#    categories_sim  distance
# 0        1.000000  1.046198
# 1        0.607998  0.730228
# 2        1.000000  0.140466
# 3        1.000000  0.015708
# 4        0.925032  0.698792
# 5        0.499441  0.061369
# 6        0.758280  0.525861
# 7        1.000000  0.119343
# 8        0.184734  1.609819
# 9        1.000000  0.118222
# 10       0.297369  0.040407
# 11       1.000000  0.759980
# 12       1.000000  0.042008
# 13       0.910723  0.659920
# 14       1.000000  0.216383
# 15       1.000000  0.003276
# 16       1.000000  1.348707
# 17       0.325079  0.032413
# 18       1.000001  0.546576
# 19       1.000000  2.723738
# 20       1.000000  0.030488
# 21       1.000000  0.072844
# 22       0.716805  0.003722
# 23       1.000000  0.205829
# 24       0.217098  0.162820
# 25       0.758280  2.955151
# 26       0.789996  0.000000
# 27       0.789996  1.758036
# 28       0.125099  0.187938
# 29       1.000000  0.142178
# 30       0.774736  0.054755
# 31       0.591006  0.193821
# 32       1.000000  0.103079
# 33       0.704953  3.040718
# 34       0.758280  1.190573
# 35       0.554826  0.021959
# 36       0.795372  0.069873
# 37       0.945767  1.046977
# 38       0.639846  0.979472
# 39       0.933986  0.030059
# 40       1.000000  0.045419
# 41       0.499441  0.029666
# 42       0.758280  0.041916
# 43       0.498931  0.046166
# 44       0.387394  0.053131
# 45       0.467228  0.186937
# 46       1.000001  0.204762
# 47       1.000000  0.016442
# 48       0.750722  0.062777
# 49       0.344821  0.371977
#
# [50 rows x 35 columns]
